# %% [markdown]
# # Linked List

# %% [markdown]
# ***

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

def traverseAndPrint(head):
  currentNode = head
  while currentNode:
    print(currentNode.data, end=" -> ")
    currentNode = currentNode.next
  print("null")

node1 = Node(7)
node2 = Node(11)
node3 = Node(3)
node4 = Node(2)
node5 = Node(9)

node1.next = node2
node2.next = node3
node3.next = node4
node4.next = node5

traverseAndPrint(node1)
traverseAndPrint(node2)
traverseAndPrint(node3)
traverseAndPrint(node4)
# Out:
# 7 -> 11 -> 3 -> 2 -> 9 -> null
# 11 -> 3 -> 2 -> 9 -> null
# 3 -> 2 -> 9 -> null
# 2 -> 9 -> null

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class Linked_list:
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0

    def append(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            self.tail = new_node

        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1

        
    def printing(self):
        
        current = self.head
        while current:
            print(current.value, end = "-> ")
            current = current.next
        print("Null")

link1 = Linked_list()
link1.append(10)
link1.append(20)
link1.append(30)
link1.append(40)
link1.append(50)

link1.printing()
# Out:
# 10-> 20-> 30-> 40-> 50-> Null

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class Linked_list:
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0

    def append(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            self.tail = new_node

        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1

    def prepend(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head = new_node
        self.length += 1

        
    def printing(self):
        
        current = self.head
        while current:
            print(current.value, end = " -> ")
            current = current.next
        print("Null")

link1 = Linked_list()
link1.append(10)
link1.append(20)
link1.append(30)
link1.append(40)
link1.append(50)

link1.prepend(5)
link1.prepend(15)

link1.printing()
# Out:
# 15 -> 5 -> 10 -> 20 -> 30 -> 40 -> 50 -> Null

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class Linked_list:
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0

    def append(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            self.tail = new_node

        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1

    def prepend(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head = new_node
        self.length += 1

    def insert_at(self, index, data):
        new_node = Node(data)
        if self.head is None:
            self.append(data)

        elif index == 0:
            self.prepend(data)

        elif index == self.length - 1 or index > self.length:
            self.append(data)

        # elif index > self.length:
        #     print("index is greater")

        else:
            current = self.head
            for i in range(index-1):
                current = current.next
            temp = current.next
            current.next = new_node
            new_node.next = temp
        self.length += 1

        
    def printing(self):
        current = self.head
        while current:
            print(current.value, end = " -> ")
            current = current.next
        print("Null")

        

link1 = Linked_list()
link1.append(10)
link1.append(20)
link1.append(30)
link1.append(40)
link1.append(50)

link1.prepend(5)
link1.prepend(15)

link1.insert_at(10, 25)

link1.printing()
# Out:
# 15 -> 5 -> 10 -> 20 -> 30 -> 40 -> 50 -> 25 -> Null

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class Linked_list:
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0

    def append(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            self.tail = new_node

        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1

    def prepend(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head = new_node
        self.length += 1

    def insert_at(self, index, data):
        new_node = Node(data)
        if self.head is None:
            self.append(data)

        elif index == 0:
            self.prepend(data)

        elif index == self.length - 1 or index > self.length:
            self.append(data)

        # elif index > self.length:
        #     print("index is greater")

        else:
            current = self.head
            for i in range(index-1):
                current = current.next
            temp = current.next
            current.next = new_node
            new_node.next = temp
        self.length += 1

    def delete_last(self):
        if self.head is None:
            print(f"Empty")
        else:
            current = self.head
            while current.next != self.tail:
                current = current.next
            current.next = None
            self.tail = current
        self.length -= 1

        
    def printing(self):
        current = self.head
        while current:
            print(current.value, end = " -> ")
            current = current.next
        print("Null")

    #  Method 2 for deleting last number
    
    # def delete_last(self):
    #     if self.head is None:
    #         print("List is empty")
    #         return
        
    #     # If only one node is present
    #     if self.head == self.tail:
    #         self.head = None
    #         self.tail = None
    #         self.length = 0
    #         return
        
    #     # Traverse until second last node
    #     current = self.head
    #     while current.next != self.tail:
    #         current = current.next
        
    #     # Remove last node
    #     current.next = None
    #     self.tail = current
    #     self.length -= 1


        

link1 = Linked_list()
link1.append(10)
link1.append(20)
link1.append(30)
link1.append(40)
link1.append(50)

link1.prepend(5)
link1.prepend(15)

link1.printing()

print("*" * 40)

# link1.insert_at(10, 25)

link1.delete_last()

link1.printing()
print("*" * 40)

link1.delete_last()
link1.printing()
# Out:
# 15 -> 5 -> 10 -> 20 -> 30 -> 40 -> 50 -> Null
# ****************************************
# 15 -> 5 -> 10 -> 20 -> 30 -> 40 -> Null
# ****************************************
# 15 -> 5 -> 10 -> 20 -> 30 -> Null

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class Linked_list:
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0

    def append(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            self.tail = new_node

        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1

    def prepend(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head = new_node
        self.length += 1

    def insert_at(self, index, data):
        new_node = Node(data)
        if self.head is None:
            self.append(data)

        elif index == 0:
            self.prepend(data)

        elif index == self.length - 1 or index > self.length:
            self.append(data)

        # elif index > self.length:
        #     print("index is greater")

        else:
            current = self.head
            for i in range(index-1):
                current = current.next
            temp = current.next
            current.next = new_node
            new_node.next = temp
        self.length += 1

    def delete_last(self):
        if self.head is None:
            print(f"Empty")
        else:
            current = self.head
            while current.next != self.tail:
                current = current.next
            current.next = None
            self.tail = current
        self.length -= 1

    def delete_first(self):
        if self.tail is None:
            print(f"Empty")
        else:
            self.head = self.head.next
            if self.head is None:
                self.tail = None
            self.length -= 1

    def delete_pos(self, index):
        if self.head is None:
            print("Empty list")
        else:
            current = self.head
            for i in range(index-1):
                current = current.next
            current.next = current.next.next

    def delete_value(self, index):
        if self.head is None:
            print("Empty list")
        elif index == 0:
            self.delete_first()
        elif index == self.length or index > self.length:
            self.delete_last()
        else:
            current = self.head
            for i in range(index-1):
                current = current.next
            current.next = current.next.next

    def remove_value(self, data):
        if self.head is None:
            print(f"Empty")
        else:
            current = self.head
            while current.next.value != data:
                current = current.next
            current.next = current.next.next

    def middle(self):
        if self.head is None:
            print("Empty")
        else:
            slow = self.head
            fast = self.head
            while fast and fast.next:
                slow = slow.next
                fast = fast.next.next
            print(slow.value)
                    

        
    def printing(self):
        current = self.head
        while current:
            print(current.value, end = " -> ")
            current = current.next
        print("Null")

        

link1 = Linked_list()
link1.append(10)
link1.append(20)
link1.append(30)
link1.append(40)
link1.append(50)

link1.prepend(5)
link1.prepend(15)

link1.insert_at(10, 25)
# link1.delete_first()

link1.printing()
print("*" * 40)

link1.delete_first()
link1.printing()
print("*" * 40)
link1.delete_pos(3)
link1.printing()
print("*" * 40)
link1.delete_value(4)
link1.printing()
print("*" * 40)
link1.remove_value(40)
link1.printing()
print("*" * 40)
link1.middle()
link1.printing()
# Out:
# 15 -> 5 -> 10 -> 20 -> 30 -> 40 -> 50 -> 25 -> Null
# ****************************************
# 5 -> 10 -> 20 -> 30 -> 40 -> 50 -> 25 -> Null
# ****************************************
# 5 -> 10 -> 20 -> 40 -> 50 -> 25 -> Null
# ****************************************
# 5 -> 10 -> 20 -> 40 -> 25 -> Null
# ****************************************
# 5 -> 10 -> 20 -> 25 -> Null
# ****************************************
# 20
# 5 -> 10 -> 20 -> 25 -> Null
